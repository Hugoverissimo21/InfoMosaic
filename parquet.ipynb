# %%
import pandas as pd

def read(dataXX):
    df = pd.read_parquet(f"{dataXX}.parquet")
    return df

# %% [markdown]
# ---

# %%
read("data01")
# Out:
#                                                                      aliases  \
# companies
# Banco Comercial Português                   [Banco Comercial Português, BCP]
# Galp Energia                                            [Galp Energia, GALP]
# EDP                        [EDP, Energias de Portugal, Electricidade de P...
# Sonae                                                           [Sonae, SON]
# Mota-Engil                                                 [Mota-Engil, EGL]
#
#                                                                     api.2000  \
# companies
# Banco Comercial Português  [{'linkToArchive': 'https://arquivo.pt/wayback...
# Galp Energia               [{'linkToArchive': 'https://arquivo.pt/wayback...
# EDP                        [{'linkToArchive': 'https://arquivo.pt/wayback...
# Sonae                      [{'linkToArchive': 'https://arquivo.pt/wayback...
# Mota-Engil                 [{'linkToArchive': 'https://arquivo.pt/wayback...
#
#                                                                     api.2003  \
# companies
# Banco Comercial Português  [{'linkToArchive': 'https://arquivo.pt/wayback...
# Galp Energia               [{'linkToArchive': 'https://arquivo.pt/wayback...
# EDP                        [{'linkToArchive': 'https://arquivo.pt/wayback...
# Sonae                      [{'linkToArchive': 'https://arquivo.pt/wayback...
# Mota-Engil                 [{'linkToArchive': 'https://arquivo.pt/wayback...
#
#                                                                     api.2006  \
# companies
# Banco Comercial Português  [{'linkToArchive': 'https://arquivo.pt/wayback...
# Galp Energia               [{'linkToArchive': 'https://arquivo.pt/wayback...
# EDP                        [{'linkToArchive': 'https://arquivo.pt/wayback...
# Sonae                      [{'linkToArchive': 'https://arquivo.pt/wayback...
# Mota-Engil                 [{'linkToArchive': 'https://arquivo.pt/wayback...
#
#                                                                     api.2009  \
# companies
# Banco Comercial Português  [{'linkToArchive': 'https://arquivo.pt/wayback...
# Galp Energia               [{'linkToArchive': 'https://arquivo.pt/wayback...
# EDP                        [{'linkToArchive': 'https://arquivo.pt/wayback...
# Sonae                      [{'linkToArchive': 'https://arquivo.pt/wayback...
# Mota-Engil                 [{'linkToArchive': 'https://arquivo.pt/wayback...
#
#                                                                     api.2012  \
# companies
# Banco Comercial Português  [{'linkToArchive': 'https://arquivo.pt/wayback...
# Galp Energia               [{'linkToArchive': 'https://arquivo.pt/wayback...
# EDP                        [{'linkToArchive': 'https://arquivo.pt/wayback...
# Sonae                      [{'linkToArchive': 'https://arquivo.pt/wayback...
# Mota-Engil                 [{'linkToArchive': 'https://arquivo.pt/wayback...
#
#                                                                     api.2015  \
# companies
# Banco Comercial Português  [{'linkToArchive': 'https://arquivo.pt/wayback...
# Galp Energia               [{'linkToArchive': 'https://arquivo.pt/wayback...
# EDP                        [{'linkToArchive': 'https://arquivo.pt/wayback...
# Sonae                      [{'linkToArchive': 'https://arquivo.pt/wayback...
# Mota-Engil                 [{'linkToArchive': 'https://arquivo.pt/wayback...
#
#                                                                     api.2018
# companies
# Banco Comercial Português  [{'linkToArchive': 'https://arquivo.pt/wayback...
# Galp Energia               [{'linkToArchive': 'https://arquivo.pt/wayback...
# EDP                        [{'linkToArchive': 'https://arquivo.pt/wayback...
# Sonae                      [{'linkToArchive': 'https://arquivo.pt/wayback...
# Mota-Engil                 [{'linkToArchive': 'https://arquivo.pt/wayback...

# %%
read("data01").map(lambda x: len(x))
# Out:
#                            aliases  api.2000  api.2003  api.2006  api.2009  \
# companies
# Banco Comercial Português        2       153       241       183       561
# Galp Energia                     2       128       389       272       582
# EDP                              3       133       339       173       653
# Sonae                            2       192       435       279       502
# Mota-Engil                       2         4        83        60       195
#
#                            api.2012  api.2015  api.2018
# companies
# Banco Comercial Português      1074      1430       954
# Galp Energia                   1156      1391       968
# EDP                            1232      1970      1096
# Sonae                          1215      1705      1196
# Mota-Engil                      538       828       560

# %% [markdown]
# ---

# %%
read("data02")
# Out:
#                                                                      aliases  \
# companies
# Banco Comercial Português                   [Banco Comercial Português, BCP]
# Galp Energia                                            [Galp Energia, GALP]
# EDP                        [EDP, Energias de Portugal, Electricidade de P...
# Sonae                                                           [Sonae, SON]
# Mota-Engil                                                 [Mota-Engil, EGL]
#
#                                                                     api.2000  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'POL | Economia | Processo ...
# Galp Energia               [{'ExtractedText': 'DN-Suplementos Negócios 10...
# EDP                        [{'ExtractedText': 'DN-Sinteses 19 de Maio de ...
# Sonae                      [{'ExtractedText': 'Radiotelevisao Portuguesa ...
# Mota-Engil                 [{'ExtractedText': 'DN-Suplementos Negócios 23...
#
#                                                                     api.2003  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'RTP RTPVídeo | Meteorologi...
# Galp Energia               [{'ExtractedText': 'RTP RTPVídeo | Meteorologi...
# EDP                        [{'ExtractedText': 'DN   27 de Setembro de 200...
# Sonae                      [{'ExtractedText': 'DN   27 de Setembro de 200...
# Mota-Engil                 [{'ExtractedText': 'RTP Empresas portuguesas s...
#
#                                                                     api.2006  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'rtp.pt ::. RTP - Rádio e T...
# Galp Energia               [{'ExtractedText': 'rtp.pt 17/01/06 ENI contin...
# EDP                        [{'ExtractedText': 'rtp.pt 16/05/06 Acessibili...
# Sonae                      [{'ExtractedText': 'rtp.pt 07/02/06 Acessibili...
# Mota-Engil                 [{'ExtractedText': 'rtp.pt 06/01/06 Euronext L...
#
#                                                                     api.2009  \
# companies
# Banco Comercial Português  [{'ExtractedText': '2003RELATÓRIO E CONTAS
# REL...
# Galp Energia               [{'ExtractedText': 'Meteorologia noticias.rtp....
# EDP                        [{'ExtractedText': 'PUBLICO.PT 24 de Maio de 2...
# Sonae                      [{'ExtractedText': 'PUBLICO.PT 24 de Maio de 2...
# Mota-Engil                 [{'ExtractedText': 'Comentários 1 a 10 de 16 E...
#
#                                                                     api.2012  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'DN - Diário de Notícias In...
# Galp Energia               [{'ExtractedText': 'PSI20 fecha a perder 0,85%...
# EDP                        [{'ExtractedText': 'EDP emite facturas rectifi...
# Sonae                      [{'ExtractedText': 'Sonae está preparada para ...
# Mota-Engil                 [{'ExtractedText': 'Administrador da Mota-Engi...
#
#                                                                     api.2015  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'DN - Diário de Notícias Si...
# Galp Energia               [{'ExtractedText': 'Lucro da Galp Energia aume...
# EDP                        [{'ExtractedText': 'EDP - PÚBLICO Saltar para ...
# Sonae                      [{'ExtractedText': 'Sonae Indústria sai do mer...
# Mota-Engil                 [{'ExtractedText': 'Mota-Engil dispara 5,9% na...
#
#                                                                     api.2018
# companies
# Banco Comercial Português  [{'ExtractedText': 'Banca | Carlos Álvares é o...
# Galp Energia               [{'ExtractedText': 'Energia - Galp Energia des...
# EDP                        [{'ExtractedText': 'EDP | PÚBLICO Ir para o co...
# Sonae                      [{'ExtractedText': 'Sonae - DN Segunda-Feira 0...
# Mota-Engil                 [{'ExtractedText': 'Mota-Engil - DN Quarta-Fei...

# %%
read("data02").map(lambda x: len(x))
# Out:
#                            aliases  api.2000  api.2003  api.2006  api.2009  \
# companies
# Banco Comercial Português        2        90       191       169       497
# Galp Energia                     2        66       233       181       469
# EDP                              3        80       245       140       538
# Sonae                            2       130       318       239       459
# Mota-Engil                       2         3        67        26       164
#
#                            api.2012  api.2015  api.2018
# companies
# Banco Comercial Português       983      1219       824
# Galp Energia                    964      1104       812
# EDP                            1076      1528       872
# Sonae                          1109      1400      1026
# Mota-Engil                      384       596       445

# %% [markdown]
# ---

# %%
read("data03")
# Out:
#                                                                      aliases  \
# companies
# Banco Comercial Português                   [Banco Comercial Português, BCP]
# Galp Energia                                            [Galp Energia, GALP]
# EDP                        [EDP, Energias de Portugal, Electricidade de P...
# Sonae                                                           [Sonae, SON]
# Mota-Engil                                                 [Mota-Engil, EGL]
#
#                                                                     api.2000  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'DN   13 de Setembro de 200...
# Galp Energia               [{'ExtractedText': 'RTP Galp reforça posição n...
# EDP                        [{'ExtractedText': 'DN-Sinteses Negocios 9 de ...
# Sonae                      [{'ExtractedText': 'DN-Sinteses 5 de Março de ...
# Mota-Engil                                                                []
#
#                                                                     api.2003  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'RTP BPI não quer lugar no ...
# Galp Energia               [{'ExtractedText': 'RTP DR Euro2004 com reserv...
# EDP                        [{'ExtractedText': 'DN   27 de Setembro de 200...
# Sonae                      [{'ExtractedText': '27 de Setembro de 2001 Son...
# Mota-Engil                 [{'ExtractedText': 'RTP Lucro da Mota-Engil so...
#
#                                                                     api.2006  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'RTP Conselho Geral do BCP ...
# Galp Energia               [{'ExtractedText': 'rtp.pt 22/03/06 Acessibili...
# EDP                        [{'ExtractedText': 'RTP Citigroup sobe preço-a...
# Sonae                      [{'ExtractedText': 'Sonaecom mantém oferta de ...
# Mota-Engil                 [{'ExtractedText': 'Brisa apresenta providênci...
#
#                                                                     api.2009  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'BCP negoceia venda da sede...
# Galp Energia               [{'ExtractedText': 'Galp Energia faz acordo co...
# EDP                        [{'ExtractedText': 'ATLETISMO: EDP - 19.ª MEIA...
# Sonae                      [{'ExtractedText': 'Sonae vai anunciar entrada...
# Mota-Engil                 [{'ExtractedText': 'Mota-Engil com oito projec...
#
#                                                                     api.2012  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'BCP pede apoio ao Estado p...
# Galp Energia               [{'ExtractedText': 'PSI20 fecha a perder 0,85%...
# EDP                        [{'ExtractedText': 'EDP emite facturas rectifi...
# Sonae                      [{'ExtractedText': 'Sonae está preparada para ...
# Mota-Engil                 [{'ExtractedText': 'Administrador da Mota-Engi...
#
#                                                                     api.2015  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'BANCO COMERCIAL PORTUGUÊS,...
# Galp Energia               [{'ExtractedText': 'Lucro da Galp Energia aume...
# EDP                        [{'ExtractedText': 'EDP - PÚBLICO Saltar para ...
# Sonae                      [{'ExtractedText': 'Sonae Indústria sai do mer...
# Mota-Engil                 [{'ExtractedText': 'Mota-Engil dispara 5,9% na...
#
#                                                                     api.2018
# companies
# Banco Comercial Português  [{'ExtractedText': 'Economia - Banco da Norueg...
# Galp Energia               [{'ExtractedText': 'Galp Energia desce em médi...
# EDP                        [{'ExtractedText': 'EDP | PÚBLICO Ir para o co...
# Sonae                      [{'ExtractedText': 'Sonae Sierra e Ocidental c...
# Mota-Engil                 [{'ExtractedText': 'Jorge Coelho volta à const...

# %%
read("data03").map(lambda x: len(x))
# Out:
#                            aliases  api.2000  api.2003  api.2006  api.2009  \
# companies
# Banco Comercial Português        2        13        34        14       147
# Galp Energia                     2         5        43         9       148
# EDP                              3        11        50        18       176
# Sonae                            2         8        21         9        90
# Mota-Engil                       2         0         4         3        47
#
#                            api.2012  api.2015  api.2018
# companies
# Banco Comercial Português       306       387       383
# Galp Energia                    335       423       375
# EDP                             297       464       440
# Sonae                           141       329       301
# Mota-Engil                       99       126       180

# %% [markdown]
# ---
