# %% [markdown]
# **todo**
#
# - ~~analise sentimento~~
#
# - ~~ner + conceitos~~
#
# - ~~tentar newsVSprice de novo, agora com menos noticias~~
#
# - ~~qty de noticias por newsSource~~
#
# - ~~word cloud com cores de cada empresa~~
#
# - grafo
#
# - corr de keywords e stock price (timeseries)
#
# - diagrama de ven, pq so temos 3 newsSources para ver q palavras algumas dizem e outras não, ou duas em comum, ...
#
#     -   e um venn para cada empresa e ver q palavras cada um tem e em comum e isso - se calhar mais vale o grafo aqui
#
# - newsVSprices com sentimentos
#
# - adicionei palavras ao set das "noticias"... dps tnh q correr isto de novo.........

# %% [markdown]
# # NER aos dados

# %%
import pandas as pd
import spacy

df = pd.read_parquet("data04.parquet")

# Load the Portuguese model
nlp = spacy.load("pt_core_news_sm")


def NER_KEYWORDS(dict):
    text = dict["ExtractedText"]
    doc = nlp(text)

    tempos = {"janeiro", "fevereiro", "março", "abril", "maio", "junho",
              "julho", "agosto", "setembro", "outubro", "novembro", "dezembro",
              "segunda-feira", "terça-feira", "quarta-feira", "quinta-feira",
              "sexta-feira", "sábado", "domingo", "fim-de-semana"}
    lixo = {"REFER", "Pedro Cunha Especial Saramago", "Angra do Heroísmo Aveiro Beja",
            "Braga Bragança Castelo Branco Coimbra"}
    noticias = {"comentários", "notícias", "artigo", "jornal", "assine", "facebook", "assinaturas",
                "online", "twitter", "instagram", "linkedin", "whatsapp", "telegram", "youtube",
                "início", "partilhar", "contactos", "newsletter", "enviar", "termos", "privacidade",
                "iniciar", "inicie", "sessão", "subscrever", "subscreva", "subscrever", "tv", "rádio",
                "conteúdos", "cookies", "opinião", "assinantes", "publicação", "edição", "edições",
                "informações", "patrocínio", "jornalismo", "entrevista", "lusa", "antena",
                "partilhe", "expresso", "público", "observador", "sábado", "paypal", "limites",
                "login", "vídeo", "entre", "programação", "newsletters", "informação", "site",
                "partilhas", "notícia", "clique", "comentário", "conteúdo", "email", "password",
                "jn", "cm", "dn", "rtp", "sic", "tvi", "limites", "índice", "imprimir",
                "perguntas frequentes", "utilizador", "sair", "reportagem", "ongoing",
                "localidade", "cinecartaz", "meteo", "perfil", "siga-nos", "dados pessoais",
                " alterar", "desporto ", "pesquisar "}

    
    # Extract named entities and filter keywords
    named_entities = [
        (ent.text, ent.label_) for ent in doc.ents
        if ent.label_ in {"PER", "ORG", "LOC", "MISC"}
        and ent.text.lower() not in tempos
        and ent.text not in lixo
        and all(w not in ent.text.lower() for w in noticias)
        and all(char.isalnum() or char in {" ", "-"} for char in ent.text)
        and len(ent.text) <= 50
    ]
    palavras_significativas = [
        token.text for token in doc 
        if token.pos_ in {"NOUN"} # {"NOUN", "VERB", "PROPN"} 
        and not token.is_stop
        and (token.text.islower() or token.text.isupper())
        and token.text.lower() not in tempos 
        and token.text not in lixo 
        and token.text.lower() not in noticias
        and token.text.isalnum()
        and len(token.text) > 3
    ]

    organized_entities = {}
    for entity, category in named_entities:
        if category not in organized_entities:
            organized_entities[category] = [entity]
        else:
            organized_entities[category].append(entity)
 
    dict["newsNER"] = organized_entities
    dict["newsNER"]["WORD"] =  palavras_significativas
    return dict

# %% [markdown]
# # analise de sentimentos
#
# - pipeline nunca dava, muito complicado
#
# - estes dois so dao em ingles e um tem mt em conta os factos, tp terrorimos etc, outro tem os sentimentos de qm fala, ent mais vale fazer uma média

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from deep_translator import GoogleTranslator

def split_text(text, chunk_size=2500):
        return [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)][:5]

def sentimentos(dict):
    texto_pt = split_text(dict["ExtractedText"])

    en_text = []
    for chunk in texto_pt:
        traducao = GoogleTranslator(source='pt', target='en').translate(chunk)
        en_text.append(traducao)
    texto_en = "".join([text for text in en_text if text is not None])

    # Initialize VADER and TextBlob
    analyzer = SentimentIntensityAnalyzer()
    blob = TextBlob(texto_en)

    # Get VADER and TextBlob sentiment scores
    vader_scores = analyzer.polarity_scores(texto_en)
    textblob_sentiment = blob.sentiment

    sentiment = vader_scores["compound"] * 0.6 + textblob_sentiment.polarity * 0.4

    dict["newsSentiment"] = sentiment
    return dict

# %% [markdown]
# # processar coluna das noticias

# %%
import random
def ProcCol(list):
    i = 0
    for i in range(len(list)):
        list[i] = NER_KEYWORDS(list[i])
        list[i] = sentimentos(list[i])
        if random.random() < 0.02:
            print(list[i]["ExtractedText"])
            print(i, i / len(list))
        i += 1
    return list

try:
    df = pd.read_parquet("data05.parquet")
except:
    df = pd.read_parquet("data04.parquet")

df["processed_news"] = None
for index, row in df.iterrows():
    if df.at[index, "processed_news"] == None:
        try:
            df.at[index, "processed_news"] = ProcCol(row["news"])

        except Exception as e:
            print(f"Error processing row {index}: {e}")
            df.at[index, "processed_news"] = None
            break

    df.to_parquet("data05.parquet")

if df["processed_news"].notna().all():
    df["news"] = df["processed_news"]
    df.drop(columns=["processed_news"], inplace=True)
    df.to_parquet("data05.parquet")
    print("Done!")

else:
    print("Not all rows were processed successfully; 'news' column was not updated.")
# Out:
# Queixa do BCP entregue ao DIAP - Sociedade - PUBLICO.PT 12 de Julho de 2010 18º - 29º Lisboa Ípsilon | Guia do lazer | Cinecartaz | Inimigo Público | Peso e Medida | | | | | | Siga-nos em: Photowalkers Uma cidade de grão em grão Fórum Espanha venceu justamente o Mundial 2010? Crónica de MEC sobre o Mundial Já passou, ainda não passou Jornal do Dia | PDF | Vídeos | Multimédia | Infografias | Blogues | Dossiers | METEO | Iniciativas | Leilões | Contactos | Assinaturas | Loja | Mundo Política Economia Desporto Sociedade Educação Ciências Ecosfera Cultura Local Media Tecnologia Mais Mais canais no PUBLICO.PT Especial África do Sul As reportagens de Alexandra Lucas Coelho e Pedro Cunha Especial Saramago Tudo sobre a vida e obra do Nobel da Literatura Edição Ultra-leve Versão ultra-leve das notícias de última hora do Publico.pt Público para Cegos Edição digital do Público para cegos Público na Escola Projecto de incentivo ao uso dos media na escola Meteorologia Previsão do tempo para os próximos dias Justiça Queixa do BCP entregue ao DIAP 12.07.2010 - 21:07 Por António Arnaldo Mesquita Votar 20 de 23 notícias em Sociedade « anterior seguinte » O Banco Comercial Português (BCP) apresentou uma queixa ao DIAP (Departamento de Investigação e Acção Penal) de Lisboa, pedindo o apuramento da autoria dos indivíduos responsáveis pelos rumores acerca de alegadas dificuldades financeiras da instituição. Um procurador do DIAP deverá agora analisar a participação do BCP e deverá encarregar os serviços de combate à criminalidade informática da Polícia Judiciária de apurar a autoria dos boatos. Corrigir Provedor do Leitor Feedback Diminuir Aumentar 230 leitores 0 comentários SIGA-NOS Twitter Facebook RSS Funcionalidades Diminuir Aumentar Comentar Imprimir Enviar Corrigir Provedor Feedback Partilhar URL desta Notícia http://publico.pt/1446424 Comentário + votado Pub Últimas + Lidas + Comentadas + Enviadas Sociedade Sorteio do Loto 2 (28º/2010) Sociedade Sorteio da Lotaria Clássica (28º/2010) Desporto Portugal sai derrotado no primeiro teste frente à Finlândia em basquetebol Local Santarém: colisão entre ligeiro e pesado de mercadorias faz um morto e um ferido ligeiro Biodiversidade PS junta-se a PSD e propõe isenção de taxas para residentes em áreas protegidas Economia Wall Street com pouco movimento fecha em alta ligeira Economia Queixa do BCP entregue ao DIAP Pub Jornal do dia jornal.publico.pt Pub Imobiliário Carga e Transportes Prontas este ano Três milhões de Euros em obras no porto da Figueira Um ano de funcionamento Aerologic com novos destinos asiáticos para carga aérea A partir desta semana com novas funcionalidades 1000 Cargas & Transportes Pub Política mais Mundo mais Desporto mais Economia mais Educação mais Sociedade mais Ecosfera mais Ciências mais Local mais Cultura mais Tecnologia mais Media mais © 2010 PÚBLICO Comunicação Social SA - Directora: Bárbara Reis - Coordenador editorial do Publico.pt: Sérgio B.
# 81 0.10037174721189591
# PCP vai pedir audição do Conselho Superior do Ministério Público sobre prescrição do caso BCP - PÚBLICO Saltar para a navegação principal Saltar para o conteúdo Público Serviços Saltar para o conteúdo Edição Impressa Loja Imobiliário Serviços Meteorologia Emprego Jogos TV Classificados Iniciativas Classificados Lisboa 26 ° C Alterar localização Localidade Definir Iniciar sessão Entrar com o Facebook Entrar com o Twitter Ou Palavra-chave Lembrar-se de mim Esqueceu-se da sua palavra-chave? Registar Pesquisa: Pesquisar Secções Saltar para o conteúdo Portugal Portugal Economia Economia Mundo Mundo Cultura Cultura Desporto Desporto Ciência Ciência Tecnologia Tecnologia Opinião Opinião Multimédia Multimédia Mais Mais Secções Saltar para o conteúdo Mercados Empresas Banca Trabalho e emprego Conjuntura Finanças públicas Internacional Empreendedorismo PCP vai pedir audição do Conselho Superior do Ministério Público sobre prescrição do caso BCP Por Lusa 22/04/2014 - 19:04 Vice-presidente do Conselho Superior da Magistratura afirmou que o tribunal "não estava preparado" para receber processos como o do BCP. Presidente e vice-presidente do Conselho Superior da Magistratura (CSM) na Comissão Parlamentar de Assuntos Constitucionais Miguel Manso  0 Partilhar no Facebook Partilhar no Twitter Partilhar no Google+ Tópicos PCP Banco de Portugal BCP Justiça Ministério Público Joana Marques Vidal Henriques Gaspar O deputado João Oliveira anunciou esta terça-feira que o PCP vai requerer a audição no Parlamento do Conselho Superior do Ministério Público (CSMP) sobre os factos que levaram à prescrição do processo contra-ordenacional que visou ex-dirigentes do BCP, como Jardim Gonçalves, que já não terá de pagar um milhão de euros em coimas. O anúncio foi feito durante a audição do presidente e vice-presidente do Conselho Superior da Magistratura (CSM) na Comissão Parlamentar de Assuntos Constitucionais para apurar as razões da prescrição, numa iniciativa que coube ao grupo parlamentar do PS. João Oliveira justificou a necessidade de ouvir, em breve, o CSMP, órgão que é presidido pela procuradora-geral da República, Joana Marques Vidal, com o facto de "o Ministério Público ter acompanhado este processo". Na sua intervenção, João Oliveira levantou questões sobre a assessoria técnica prestada no processo contra-ordenacional do BCP e disse ver com "pouco agrado" as soluções de mero alargamento dos prazos prescricionais para resolver o problema. Questionou ainda os responsáveis do CSM sobre se não seria preferível que este tipo de processo seguisse logo para a esfera criminal, evitando a morosidade da fase administrativa do processo. Na audição desta terça-feira, Henriques Gaspar, presidente do Supremo Tribunal de Justiça e do CSM, reconheceu que a prescrição do caso contra-ordenacional do BCP "teve repercussão e que os cidadãos exigem informações adequadas", observando que "todas as situações têm uma explicação", mesmo aquelas que são "anómalas". Apesar de admitir que o CSM não tem ainda uma posição colectiva sobre o caso das prescrições contra-ordenacionais, Henriques Gaspar não deixou de criticar a "avalancha legislativa em matéria de contra-ordenações", que, na sua perspectiva, criou "uma manta de retalhos" naquele domínio do direito. Reconheceu ainda que, neste campo, os tribunais estão "a trabalhar com um modelo desadaptado à sua história" e que é "essencial" e "prioritário" manter "a confiança" dos cidadãos no sistema, insistindo que essa é a sua principal preocupação. Na mesma sessão, o vice-presidente do CSM, António Joaquim Piçarra, admitiu que o Tribunal de Pequena Instância Criminal "não estava preparado" para receber processos com a dimensão e complexidade do caso contra-ordenacional do BCP. Joaquim Piçarra revelou que o CSM tomou conhecimento do caso BCP a 11 de Março, pela comunicação social, tendo mandado realizar uma "averiguação sumária" e, com base nela, instaurado um "inquérito". Adiantou que do inquérito realizado resultou que "não ha ...
# 160 0.1982651796778191
# BCP aposta na venda de casas 'low cost' - Especiais - DN Início Política Desporto Cartaz Vídeos Especiais Galerias Arquivo 11-09-2012  |   |   |  login DN Mobile | Iniciativas DN | Assine o DN | Classificados | Loja do Jornal Portugal Globo Economia Ciência Artes TV & Media Opinião Pessoas Revistas de Imprensa BCP aposta na venda de casas 'low cost' por Lina Santos   O banco Millenium BCP aderiu à venda de imóveis em regime 'low cost' este mês. As casas resultam, na maioria, da recuperação de crédito. Todos estão a ser vendidos a preços reduzidos. Nenhum dos imóveis supera a fasquia dos 50 mil euros. Quase um terço destas casas está já vendida segundo o próprio banco, avança o " Jornal de Negócios ". A campanha começou no dia 1 de agosto e tem a duração de dois meses, acrescenta a entidade bancária. São casas cujos preços começam nos 12 500 euros e que não têm sido tão divulgadas como outros imóveis que o Millenium BCP tem à venda. Ao todo são 53 imóveis, entre apartamentos e vivendas. Patrocínio   3247 Visualizações 3 Impressões 6 Comentários 8 Envios Ferramentas Enviar por Email Partilhar Imprimir Aumentar Texto Diminuir Texto Comentar este Artigo FERRAMENTAS   Enviar Partilhar Imprimir Comentar este Artigo Aumentar Texto Diminuir Texto   PARTILHAR NOTíCIA   TAGS   revista de imprensa   ULTIMOS COMENTÁRIOS Anónimo COMPREM COMPREM, DEPOIS NÃO SE ... há 18 dias e 15 horas Anónimo A LEI DEVIA PROIBIR A VENDA DE ... há 18 dias, 15 horas e 22 minutos Poe-tefino E onde encontro este imoveis,Algum ... há 18 dias, 17 horas e 57 minutos Comentários Reacções no Twitter CONTEÚDO EVENTUALMENTE OFENSIVO Por opção editorial, o exercício da liberdade de expressão é total, sem limitações, nas caixas de comentários abertas ao público disponibilizadas pelo Diário de Notícias em www.dn.pt. Os textos aí escritos podem, por vezes, ter um conteúdo susceptível de ferir o código moral ou ético de alguns leitores, pelo que o Diário de Notícias não recomenda a sua leitura a menores ou a pessoas mais sensíveis. As opiniões, informações, argumentações e linguagem utilizadas pelos comentadores desse espaço não refletem, de algum modo, a linha editorial ou o trabalho jornalístico do Diário de Notícias. Os participante são incentivados a respeitar o Código de Conduta do Utilizador e os Termos de Uso e Política de Privacidade, que podem ser lidos neste endereço: http://www.dn.pt/info/termosdeuso.aspx O Diário de Notícias reserva-se o direito de proceder judicialmente ou de fornecer às autoridades informações que permitam a identificação de quem use as caixas de comentários em www.dn.pt para cometer ou incentivar atos considerados criminosos pela Lei Portuguesa, nomeadamente injúrias, difamações, apelo à violência, desrespeito pelos símbolos nacionais, promoção do racismo, xenofobia e homofobia ou quaisquer outros. Ordenar por: Data Nº de Respostas « ... | | ... » « ... | | ... » Comentar Comentário Caracteres disponíveis: 750 Receber alerta de resposta Aparecer como Anónimo Lembrar dados pessoais Nota: Os comentários deste site são publicados sem edição prévia e são da exclusiva responsabilidade dos seus autores. Consulte a Conduta do Utilizador , prevista nos Termos de Uso e Política de Privacidade . O DN reserva-se ao direito de apagar os comentários que não cumpram estas regras. Receber alerta de resposta - será enviado um alerta para o seu e-mail sempre que houver uma resposta ao seu comentário. Aparecer como anónimo - os dados (nome e-mail) são ocultados. Os comentários podem demorar alguns segundos para ficarem disponíveis no site. Se tem conta, faça Login Nome do utilizador Password login » Se não tem conta, Registe-se aqui Esqueceu-se da password? Legenda Utilizador Registado    Utilizador Não Registado Siga-nos no Notícias     Juiz manda examinar dentes de 63 arguidos   Juíza solta chefes do crime na PSP   Entrega da casa não basta para pagar empréstimo   Medo, vem aí mais austeridade   Orçamento de 2013 vai ter ainda mais austeridade   Pimenta Ma ...
# 200 0.24783147459727387
# BCP negocia venda de subsidiária grega ao Piraeus - PÚBLICO Saltar para a navegação principal Saltar para o conteúdo Sites Público Saltar para o conteúdo Público Fugas Life&Style P3 Ípsilon Cinecartaz Guia do Lazer Inimigo Público 22.02.2013 Lisboa 11 ° C Alterar localização Localidade Definir Público Úteis Saltar para o conteúdo Assinaturas Jornal do Dia Emprego Serviços Meteorologia Loja Jogos TV Classificados Imobiliário Iniciativas Almas Gémeas Cargas e Transportes Siga-nos Saltar para o conteúdo Facebook Twitter Google+ RSS Iniciar sessão Entrar com o Facebook Entrar com o Twitter Ou Palavra-chave Lembrar-se de mim Esqueceu-se da sua palavra-chave? Registar Pesquisa: Pesquisar Navegação Saltar para o conteúdo Portugal Portugal Economia Economia Mundo Mundo Cultura Cultura Desporto Desporto Ciência Ciência Tecnologia Tecnologia Opinião Opinião Multimédia Multimédia Secções Saltar para o conteúdo Mercados Empresas Banca Trabalho e emprego Conjuntura Finanças públicas Internacional Empreendedorismo BCP negocia venda de subsidiária grega ao Piraeus Por PÚBLICO e Lusa 06/02/2013 - 17:20 O BCP está a negociar em exclusivo com o Piraeus a alienação do Millennium Bank, a instituição financeira que detém na Grécia. Grupo BCP está à procura de uma solução para o negócio grego Nuno Ferreira Santos  1 Partilhar no Facebook Partilhar no Twitter Partilhar no Google+ Tópicos Grécia Banca BCP De acordo com o comunicado enviado ao regulador do mercado de capitais, a CMVM, o BCP confirma que, “no contexto da análise das diferentes alternativas anunciadas em relação à sua subsidiária grega, decidiu iniciar negociações, que actualmente têm carácter de exclusividade, com o Piraeus Bank”, no sentido de alienar o Millennium Bank. De acordo com o BCP, as negociações estão a decorrer, mas “nenhuma decisão foi ainda tomada”. O banco acrescenta ainda que, apesar das negociações, “nenhuma decisão foi ainda tomada por qualquer das partes, pelo que nenhuma decisão de investimento deve ser tomada com base na perspectiva sobre o desfecho destas negociações” e remete novas informações para mais tarde. A unidade do BCP na Grécia teu causado sucessivas dores de cabeça à instituição financeira, que já há algum tempo tem mostrado interesse em sair daquele país. Nos primeiros nove meses do ano, até Setembro, o BCP registou prejuízos de 796,3 milhões de euros, para que contribuíram mais de 500 milhões de euros reservados para perdas que podem vir a acontecer com a operação do banco na Grécia. Os resultados do total do ano de 2012 serão conhecidos esta sexta-feira. Já em 2011 o banco apresentou um prejuízo de 786 milhões de euros. Então, o banco referiu os factores extraordinários que ascenderam a 972 milhões de euros, a grande fatia dos quais devido às imparidades (perdas potenciais) relacionadas com a Grécia.  1 Partilhar no Facebook Partilhar no Twitter Partilhar no Google+ Outros Artigos Empréstimo do Estado ao BCP custará 250 milhões de euros este ano BCP com prejuízo recorde de 1200 milhões de euros Técnicos de Bruxelas em Portugal para discutir reestruturação dos bancos Onda de despedimentos nos bancos vai continuar em 2013 Comentários Comentar Inicie sessão ou registe-se gratuitamente para assinar os comentários. Caracteres restantes: Critérios de publicação Nos Blogues Anterior CP teve prejuízo de 222,5 milhões de euros em 2012 Seguinte Parlamento Europeu aprova nova política para a pesca sustentável Pub Últimas Notícias 18:19 Arguidos do caso BCP recorreram todos da sentença 17:49 Reacções às previsões da Comissão Europeia 16:09 PSA de Mangualde recupera terceiro turno 15:23 Governo reestrutura porto de Lisboa com 80% de investimento privado 15:06 Mota Engil lança 75 milhões em obrigações Mais populares O que é isto? Economia : Consumidores pedem facturas em nome de Passos Coelho Tecnologia : É uma caneta, escreve em 3D e já é um fenómeno do crowdfunding Política : Passos defende que protestos "não são representativos da sociedade portuguesa” Mundo :  ...
# 229 0.28376703841387857
# BES e BCP preparam aumentos de capital - Especiais - DN Início Política Desporto Cartaz Vídeos Especiais Galerias Arquivo Notícias Magazine  |   |   |  login/registo DN Mobile | Iniciativas DN | Assine o DN | Classificados | Loja do Jornal Portugal Globo Economia Ciência Artes TV & Media Opinião Pessoas Revistas de Imprensa BES e BCP preparam aumentos de capital por L.M.C.   BES prepara aumento de capital até aos mil milhões de euros, a arrancar nas próximas semanas. Millennium bcp estuda reforço acima de 1,5 milhões, acelerando reembolso de "CoCo bonds" ao Estado. O "Diário Económico" escreve hoje que "os dois maiores bancos privados portugueses estão a preparar a realização de aumentos de capital, aproveitando o crescente apetite dos investidores internacionais pela banca do Sul da Europa. O BES e o Millennium bcp poderão anunciar nos próximos dias ou semanas os respetivos aumentos de capital, com vista a reforçarem os rácios e, no caso do banco liderado por Nuno Amado, a acelerar o reembolso de "CoCo nonds" ao Estado. Em cima da mesa estará um aumento de capital até mil milhões de euros no BES, enquanto no BCP o montante em estudo será superior a 1,5 mil milhões de euros. Fontes oficiais dos dois bancos escusaram-se a confirmar a realização de aumentos de capital". Patrocínio   180 Visualizações 3 Impressões 0 Comentários 0 Envios Ferramentas Enviar por Email Partilhar Imprimir Aumentar Texto Diminuir Texto Comentar este Artigo FERRAMENTAS   Enviar Partilhar Imprimir Comentar este Artigo Aumentar Texto Diminuir Texto   PARTILHAR NOTíCIA   RELACIONADO   Socialistas incentivam António Guterres a candidatar-se Cadeias gastam 19 milhões sem controlo Conselho Superior da Magistratura castiga 36 juízes CNE aprovou à tangente Conselho de Ministros e BCE Salários do Estado até mil euros caem em 2015 TAGS   Diário Económico , BCP , capital , revista de imprensa , Bancos , BES Comentários Reacções no Twitter CONTEÚDO EVENTUALMENTE OFENSIVO Por opção editorial, o exercício da liberdade de expressão é total, sem limitações, nas caixas de comentários abertas ao público disponibilizadas pelo Diário de Notícias em www.dn.pt. Os textos aí escritos podem, por vezes, ter um conteúdo susceptível de ferir o código moral ou ético de alguns leitores, pelo que o Diário de Notícias não recomenda a sua leitura a menores ou a pessoas mais sensíveis. As opiniões, informações, argumentações e linguagem utilizadas pelos comentadores desse espaço não refletem, de algum modo, a linha editorial ou o trabalho jornalístico do Diário de Notícias. Os participantes são incentivados a respeitar o Código de Conduta do Utilizador e os Termos de Uso e Política de Privacidade, que podem ser lidos neste endereço: http://www.dn.pt/info/termosdeuso.aspx O Diário de Notícias reserva-se o direito de proceder judicialmente ou de fornecer às autoridades informações que permitam a identificação de quem use as caixas de comentários em www.dn.pt para cometer ou incentivar atos considerados criminosos pela Lei Portuguesa, nomeadamente injúrias, difamações, apelo à violência, desrespeito pelos símbolos nacionais, promoção do racismo, xenofobia e homofobia ou quaisquer outros. Ordenar por: Data Nº de Respostas « ... | | ... » « ... | | ... » Comentar Comentário Caracteres disponíveis: 750 Receber alerta de resposta Aparecer como Anónimo Lembrar dados pessoais Nota: Os comentários deste site são publicados sem edição prévia e são da exclusiva responsabilidade dos seus autores. Consulte a Conduta do Utilizador , prevista nos Termos de Uso e Política de Privacidade . O DN reserva-se ao direito de apagar os comentários que não cumpram estas regras. Receber alerta de resposta - será enviado um alerta para o seu e-mail sempre que houver uma resposta ao seu comentário. Aparecer como anónimo - os dados (nome e-mail) são ocultados. Os comentários podem demorar alguns segundos para ficarem disponíveis no site. Se tem conta, faça Login Email Password login » Se não tem conta, Registe-se a ...
# 283 0.3506815365551425
# BCP - PÚBLICO Saltar para a navegação principal Saltar para o conteúdo × Este site utiliza cookies. Registar Pesquisa: Pesquisar Secções Saltar para o conteúdo Portugal Portugal Economia Economia Mundo Mundo Cultura-Ípsilon Cultura-Ípsilon Desporto Desporto Ciência Ciência Tecnologia Tecnologia Opinião Opinião Multimédia Multimédia Mais Mais BCP Todos os tópicos BCP lança oferta de troca de dívida por acções do banco Por Rosa Soares 18/04/2015 Capital aumentará em 428 milhões de euros, se for integralmente aceite. BCP lança oferta de troca de dívida por acções do banco Por Rosa Soares 18/04/2015 Capital aumentará em 428 milhões de euros, se for integralmente aceite. BCP encaixa 304 milhões com venda de participação na Polónia 26/03/2015 Banco reduz posição mas fica ainda com 50,1% do Bank Millennium. Um debate essencial num país sem estratégia desde que aderiu à União Europeia BCP vai vender 15,41% do seu banco na Polónia Por PÚBLICO 25/03/2015 Instituição mantém maioria do capital.
# 400 0.49566294919454773
# BCP - PÚBLICO Saltar para a navegação principal Saltar para o conteúdo × Este site utiliza cookies. Registar Pesquisa: Pesquisar Secções Saltar para o conteúdo Portugal Portugal Economia Economia Mundo Mundo Cultura-Ípsilon Cultura-Ípsilon Desporto Desporto Ciência Ciência Tecnologia Tecnologia Opinião Opinião Multimédia Multimédia Mais Mais BCP Todos os tópicos Montepio e Banif contrariam tendência de captação de poupanças Por Pedro Crisóstomo 08/12/2015 CGD e BPI conseguiram compensar queda dos depósitos na actividade em Portugal com um aumento de outros recursos de clientes até Setembro. O BCP, a CGD e o BPI. Vídeo CGD, BCP, BPI, Totta e Banif com lucros de 600 milhões Por Cristina Ferreira 12/11/2015 Montepio destacou-se pela negativa com prejuízo de 59,5 milhões entre Janeiro e Setembro. BCP passa de prejuízo para lucro de 264,5 milhões Por Cristina Ferreira 02/11/2015 Resultados dos nove primeiros meses do ano.
# 433 0.5365551425030979
# BCP - PÚBLICO Saltar para a navegação principal Saltar para o conteúdo × Este site utiliza cookies. Registar Pesquisa: Pesquisar Secções Saltar para o conteúdo Política Política Sociedade Sociedade Mundo Mundo Economia Economia Cultura-Ípsilon Cultura-Ípsilon Ciência Ciência Desporto Desporto Tecnologia Tecnologia Opinião Opinião Mais Mais BCP Todos os tópicos Oxy Capital fica com a unidade de aquicultura em Mira Por Isabel Aveiro 11/07/2017 CGD, BCP e Novo Banco decidiram pela execução extrajudicial da penhora sobre a Acuinova, antiga empresa da Pescanova dona da unidade de aquicultura em Mira. Oxy Capital fica com a unidade de aquicultura em Mira Por Isabel Aveiro 11/07/2017 CGD, BCP e Novo Banco decidiram pela execução extrajudicial da penhora sobre a Acuinova, antiga empresa da Pescanova dona da unidade de aquicultura em Mira. BCP, Caixa e Novo Banco vendem posições que detinham na Acuinova Por Lusa 03/07/2017 Três dos bancos portugueses credores da Acuinova-Mira (Millennium BCP, Caixa Geral de Depósitos e Novo Banco), venderam a totalidade das acções que detinham na empresa portuguesa à Ondas e Versos, foi hoje anunciado pelo grupo Nueva Pescanova. Principal accionista do BCP entre os grupos analisados por regulador chinês Por Luís Villalobos 22/06/2017 Supervisor dos bancos da China quer conhecer risco dos empréstimos feitos a empresas como a Fosun e a HNA, ligada à TAP.
# 556 0.6889714993804213
# Banca - BCP à procura de investidores estrangeiros para se financiar em 300 milhões Sexta-Feira 24 de novembro de 2017 23:27 Fundado em 29 de dezembro de 1864 Menu Últimas Notícias Portugal Desporto Mundo Opinião Dinheiro Sociedade Artes Pessoas Media Fotogalerias Vídeos Mais Evasões Dinheiro Vivo Notícias Magazine Publicidade Área Pessoal Diário de Notícias 24 NOVEMBRO 2017 Assinar o DN Conheça a nossa app móvel App Store Google Play Dinheiro BCP à procura de investidores estrangeiros para se financiar em 300 milhões Siga-nos Siga-nos no Facebook Siga-nos no Twitter Siga-nos no Google + meteo Lisboa 24 NOVEMBRO 2017 HOJE 21º SÁBADO 19º DOMINGO 19º SEGUNDA 17º TERÇA 18º QUARTA 17º QUINTA 15º LOCALIDADE (Portugal) Angra do Heroísmo Aveiro Beja Braga Bragança Castelo Branco Coimbra Évora Faro Funchal Guarda Horta Leiria Lisboa Ponta Delgada Portalegre Porto Santarém Santa Cruz das Flores Setúbal Viana do Castelo Vila Real Viseu Assinatura Newsletters Pesquisar Pesquisar t-main-featured-1 BCP à procura de investidores estrangeiros para se financiar em 300 milhões 24 DE NOVEMBRO DE 2017 O BCP é o próximo. O objetivo do BCP é, segundo a Reuters, obter financiamento de 300 milhões de euros em títulos a dez anos. No caso do BCP, esta emissão poderá ajudar a diversificar as fontes de financiamento. O BCP lucrou 133,3 milhões de euros, o que compara com as perdas de 251,1 milhões no mesmo período de 2016. A montar a emissão e a organizar os encontros com investidores estão, além do BCP, o Goldman Sachs, o Société Générale e o UBS. 0 banca 24 DE NOVEMBRO DE 2017 01:07 Rui Barroso Facebook Twitter Google Plus Comentários Partilhas Enviar por Email Imprimir bcp dinheiro papel Últimas notícias 2017-11-24 Nuno Magalhães "Acho inconcebível" que as secretas não possam "fazer escutas" "Obviamente que o fazem [escutas]", mas sem fiscalização, acrescentou Nuno Magalhães Partilhar Facebook Twitter Google Plus 2017-11-24 legionella Balneários da academia da Académica de Coimbra foram encerrados Partilhar Facebook Twitter Google Plus 2017-11-24 Espanha Estrela Michelin para restaurante que devia estar fechado Partilhar Facebook Twitter Google Plus 2017-11-24 relatório Governo divulga parte do oculto capítulo 6 sobre incêndios de Pedrógão É o capítulo faz uma análise detalhada a casos de sobrevivência, a vítimas mortais encontradas e a problemas nas comunicações Partilhar Facebook Twitter Google Plus 2017-11-24 Madeira Mau tempo impede aterragem e avião regressa a Lisboa Partilhar Facebook Twitter Google Plus 2017-11-24 Vieira da Silva "A exceção era pagar os subsídios em duodécimos" Partilhar Facebook Twitter Google Plus 2017-11-24 jogos Jackpot de 80 milhões no Euromilhões Partilhar Facebook Twitter Google Plus Brand Story Tui Mais popular no dn.pt Dinheiro Mais Menos Mais Menos Pub Pub Enviar Secções Portugal Desporto Mundo Opinião Dinheiro Sociedade Artes Pessoas Media Fotogalerias Vídeos Suplementos Evasões Dinheiro Vivo Notícias Magazine O site Termos & Condições Ficha Técnica Contactos Siga-nos Facebook Twitter Google + Linkedin Serviços Assinaturas Loja do Jornal Fundado em 29 de dezembro de 1864 Email Marketing Certified by E-goi Diário de Notícias, 2015 © Todos os direitos reservados | Termos de Uso e Política de Privacidade | Ficha Técnica | Publicidade | Contactos
# 572 0.7087980173482032
# Sonangol vai manter participações na GALP e no Millennium BCP - Economia - RTP Notícias Toggle Menu Notícias Desporto Televisão RTP1 A Praça Agora Nós Telejornal Sexta às 9 Linha da Frente 5 Para a Meia-Noite O Sábio Brainstorm 2077 - 10 segundos para o Futuro Excursões Air Lino Ver programação RTP1 RTP2 Literatura Aqui Página 2 Sociedade Civil Desporto 2 Cinemax Zig Zag Olhar o Mundo História a História: África Ver programação RTP2 RTP3 360º As Horas Extraordinárias Grande Entrevista Grande Área O Último Apaga a Luz O Príncipio da Incerteza Trio d`Ataque O outro lado Ver programação RTP3 RTP Memória Ver programação de todos os canais RTP África RTP Internacional RTP Açores RTP Madeira Rádio Antena1 Portugalex Maria Flor Pedroso Cinemax Viva a Música David Ferreira a contar O Amor é Entrevista Antena 1 / Jornal de Negócios - Uma Conversa Capital Ver programação Antena1 Antena2 Argonauta A propósito da música A Ronda da Noite Fuga da Arte Jazz a 2 Música Aeterna O Tempo e a Música Quinta Essência Raízes Um Certo Olhar Ver programação Antena2 Antena3 No Ar Antena3 Docs Domínio Público Prova Oral O Disco Disse Portugália A3.30 Manhãs da 3 Indiegente Mata-bicho Ver programação Antena3 RDP África Ver toda a programação de rádio RDP Internacional RDP Açores RDP Madeira Antena1 RDP Madeira Antena3 Antena1 Lusitânia Antena1 Vida Antena1 Fado Antena2 Ópera Antena 1 Memória Rádio Zig Zag Antena 2 Jazz In RTP Play ZigZag Arquivos + Rede RTP Ensina RTP Museu RTP Newsletters RTP Academia RTP RTP Arena Extra RTP Lab RTP: Nosso Futuro Aplicações móveis RTP Play RTP Notícias Zig Zag Play Brainstorm App Got Talent PT A empresa Contactos Candidaturas Espontâneas Organograma RTP+ Informação Financeira Contrato de concessão do serviço público de Rádio e de Televisão Provedor do Telespetador Provedor do Ouvinte Institucional Identidade gráfica Apoios e Parcerias Anunciar Consulta de conteúdos de rádio Aplicações móveis Consulta de Conteúdos Cinematográficos Concursos Perguntas frequentes Contactos Toggle Found %s Results Notícias | Toggle Menu Desporto País Mundo Política Economia Cultura Vídeos Áudios Opinião Taça da Confederações Olimpicos 2016 Euro 2016 Presidenciais 2016 Liga dos Campeões Em Foco Eleições 2015 Imagem do Dia Galeria Tempo Trânsito Infografias Bolsa RSS + Opinião Taça da Confederações Olimpicos 2016 Euro 2016 Presidenciais 2016 Liga dos Campeões Em Foco Eleições 2015 Imagem do Dia Galeria Tempo Trânsito Infografias Bolsa RSS Partilhe no Facebook Partilhe no Twitter Partilhe no Google+ Partilhe no Linkedin Partilhe no Whatsapp Sonangol vai manter participações na GALP e no Millennium BCP Lusa 28 Fev, 2018, 15:12 / atualizado em 28 Fev, 2018, 15:12 | Economia | Siphiwe Sibeko - Reuters A Sonangol vai manter as participações que tem no capital social da GALP e no Millennium BCP por se trataram de "investimentos estratégicos", garantiu hoje em Luanda o presidente do Conselho de Administração da petrolífera angolana, Sonangol. Segundo Carlos Saturnino, que falava numa conferência de imprensa, no âmbito das comemorações dos 42 anos de existência da empresa angolana, aqueles dois investimentos são estratégicos e dão "bons resultados". "O investimento na GALP é um bom investimento. A GALP está envolvida em concessões petrolíferas e outras atividades não só em Portugal, na Península Ibérica, tem investimentos em Angola, em vários blocos, tem investimentos muito interessantes e sonantes a nível do Brasil, de maneira que é um investimento estratégico e que tem dado bons resultados", disse Carlos Saturnino. Relativamente ao Millennium BCP, o presidente do Conselho de Administração da Sonangol salientou que o banco "melhorou substancialmente, tem produzido dinheiro, tem produzido resultados, não tem distribuído grandes montantes, mas é um banco que tem adicionado valores através da sua atividade". "Ou seja, por cada euro investido, o banco hoje gera valor adicionado, para a organização que o banco continua a reinvestir, ainda não deu o salto ...
# 654 0.8104089219330854
# BCP na Polónia compra Eurobank por 428 milhões Diário de Notícias Menu Pesquisar Cidades Poder País Mundo Cultura Desportos Opinião Vida e futuro Ócio Life Insider Edição do dia 1864 Login Minha conta Alterar Dados Pessoais Mudar de Utilizador Sair Pesquisar Fechar Início Dinheiro BCP na Polónia compra Eurobank por 428 milhões O BCP da Polónia acordou uma participação de 99,79% no Eurobank, uma subsidiária da Société Générale S.A., reforçando a posição na banca polaca.. Dinheiro Vivo 05 Novembro 2018 — 08:31 Facebook Twitter Comentar Partilhar Tópicos Bancos Dinheiro Vivo dinheiro O Bank Millennium, detido pelo Banco Comercial Português, chegou esta segunda-feira a um acordo para a aquisição de uma participação de 99,79% no Eurobank, pertencente à Societe Generale Financial Services Holding, uma subsidiária da Société Générale S.A.. Leia mais em Dinheiro Vivo a sua marca de economia Comentários Ler mais BCP na Polónia compra Eurobank por 428 milhões Facebook Twitter Partilhar Exclusivos Premium Desporto Futebol.
# 665 0.8240396530359355
# AG do BCP arrancou com 62% capital presente Diário de Notícias Menu Pesquisar Cidades Poder País Mundo Cultura Desportos Opinião Vida e futuro Ócio Life Insider Edição do dia 1864 Login Minha conta Alterar Dados Pessoais Mudar de Utilizador Sair Pesquisar Fechar Início Dinheiro AG do BCP arrancou com 62% capital presente Dinheiro Vivo 05 Novembro 2018 — 16:01 Facebook Twitter Partilhar Tópicos Dinheiro Vivo Banca Relacionados banca Acionistas do BCP dão primeiro passo para distribuição de dividendos A assembleia geral extraordinária (AGE) de acionistas do Millennium bcp, que decorre esta segunda-feira, visando abrir portas para a distribuição de dividendos, arrancou com 62% do capital do banco representado. Leia mais em Dinheiro Vivo a sua marca de economia Ler mais AG do BCP arrancou com 62% capital presente Facebook Twitter Partilhar Exclusivos Premium Brasil O juiz, o liberal, o astronauta, o pastor e os generais.
# 675 0.8364312267657993
# Banco BCP aumentou lucros em 61,5% em 2018 para 301,1 ME - Economia - RTP Notícias Toggle Menu Notícias Desporto Televisão RTP1 A Praça Agora Nós Telejornal Sexta às 9 Linha da Frente 5 Para a Meia-Noite Donos Disto Tudo The Voice Portugal Joker Circo Paraíso Cosido à Mão 3 Mulheres Famílias Frente a Frente Cá por Casa Os Filhos do Rock Odisseia Depois do Adeus Festival da Canção Ver programação RTP1 RTP2 Visita Guiada Literatura Aqui Sociedade Civil Desporto 2 Cinemax Zig Zag História a História: África Folha de Sala Idiotas, ponto. Sara Super Diva - Ópera Para Todos Ver programação RTP2 RTP3 Olhar o Mundo 360º As Horas Extraordinárias Grande Entrevista Grande Área Trio d`Ataque O outro lado Fronteiras XXI Ver programação RTP3 RTP Memória Ver programação de todos os canais RTP África RTP Internacional RTP Açores RTP Madeira Rádio Antena1 Portugalex Maria Flor Pedroso Cinemax Viva a Música David Ferreira a contar O Amor é Entrevista Antena 1 / Jornal de Negócios - Uma Conversa Capital Ver programação Antena1 Antena2 Argonauta A propósito da música A Ronda da Noite Fuga da Arte Jazz a 2 Música Aeterna O Tempo e a Música Quinta Essência Raízes Um Certo Olhar Ver programação Antena2 Antena3 No Ar Antena3 Docs Domínio Público Prova Oral O Disco Disse Portugália A3.30 Manhãs da 3 Indiegente Ver programação Antena3 RDP África Ver toda a programação de rádio RDP Açores RDP Internacional RDP Madeira Antena1 RDP Madeira Antena3 Antena1 Fado Antena1 Lusitânia Antena 1 Memória Antena1 Vida Antena 2 Jazz In Antena2 Ópera Rádio Zig Zag RTP Play ZigZag Arquivos + Rede RTP Ensina RTP Museu RTP Newsletters RTP Academia RTP RTP Arena Extra RTP Lab RTP: Nosso Futuro Aplicações móveis RTP Play RTP Notícias Zig Zag Play Brainstorm App Got Talent PT A empresa Contactos Candidaturas Espontâneas Organograma RTP+ Provedor do Telespetador Informação Financeira Contrato de concessão do serviço público de Rádio e de Televisão Consulta de Conteúdos Cinematográficos Provedor do Ouvinte Sandbox RTP Institucional Identidade gráfica Apoios e Parcerias Anunciar Aplicações móveis Concursos Perguntas frequentes Contactos RGPD Gestão das definições de Cookies Toggle Found %s Results Notícias | Toggle Menu Desporto País Mundo Política Economia Cultura Vídeos Áudios RTP Europa Em Foco Imagem do Dia Galeria Tempo Infografias RSS + RTP Europa Em Foco Imagem do Dia Galeria Tempo Infografias RSS Partilhe no Facebook Partilhe no Twitter Partilhe no Google+ Partilhe no Linkedin Partilhe no Whatsapp Banco BCP aumentou lucros em 61,5% em 2018 para 301,1 ME Lusa 21 Fev, 2019, 18:18 | Economia O banco BCP teve lucros de 301,1 milhões de euros em 2018, mais 61,5% do que os resultados de 2017, divulgou hoje o presidente executivo, Miguel Maya, em conferência de imprensa. Antes da apresentação das contas de 2018, o presidente do Conselho de Administração, Nuno Amado, fez uma intervenção inicial em que destacou o plano de reestruturação que o banco passou nos últimos anos, que considerou "coerente, complexo, bem implementado" e que permitiu ao BCP, depois de anos de prejuízos em 2013, 2014 e 2015, ter regressado aos lucros em 2015, 2016, 2017 e 2018. "Apresentamos resultados positivos, crescentes e consistentes. Vamos ao ritmo certo", considerou Amado, que em julho do ano passado deixou de ser presidente executivo (cargo que ocupava desde 2012) e passou a presidente do Conselho de Administração (`chairman`, não executivo). Partilhar o artigo Banco BCP aumentou lucros em 61,5% em 2018 para 301,1 ME Imprimir o artigo Banco BCP aumentou lucros em 61,5% em 2018 para 301,1 ME Enviar por email o artigo Banco BCP aumentou lucros em 61,5% em 2018 para 301,1 ME Aumentar a fonte do artigo Banco BCP aumentou lucros em 61,5% em 2018 para 301,1 ME Diminuir a fonte do artigo Banco BCP aumentou lucros em 61,5% em 2018 para 301,1 ME Ouvir o artigo Banco BCP aumentou lucros em 61,5% em 2018 para 301,1 ME Pub Últimos Artigos Últimas Últimas + Lidas + Coment. 1 Coronel confirmou disparos de milit ...
# 725 0.8983890954151177
# BCP confirma que Sabadell quer vender participação de 4,08% no banco português - Economia - RTP Notícias Toggle Menu Notícias Desporto Televisão RTP1 A Praça da Alegria Telejornal 5 Para a Meia-Noite Joker Cá por Casa Festival da Canção A Nossa Tarde Ver programação RTP1 RTP2 Visita Guiada Literatura Aqui Sociedade Civil Desporto 2 Cinemax Zig Zag Folha de Sala Ver programação RTP2 RTP3 Olhar o Mundo 360º As Horas Extraordinárias Grande Entrevista Grande Área Trio d`Ataque O outro lado Fronteiras XXI Ver programação RTP3 RTP Memória Ver programação de todos os canais RTP África RTP Internacional RTP Açores RTP Madeira Rádio Antena1 Portugalex Maria Flor Pedroso Cinemax Viva a Música David Ferreira a contar O Amor é Entrevista Antena 1 / Jornal de Negócios - Uma Conversa Capital Ver programação Antena1 Antena2 Argonauta A propósito da música A Ronda da Noite Fuga da Arte Jazz a 2 Música Aeterna O Tempo e a Música Quinta Essência Raízes Um Certo Olhar Ver programação Antena2 Antena3 No Ar Antena3 Docs Domínio Público Prova Oral O Disco Disse Portugália A3.30 Manhãs da 3 Indiegente Ver programação Antena3 RDP África Ver toda a programação de rádio RDP Açores RDP Internacional RDP Madeira Antena1 RDP Madeira Antena3 Antena1 Fado Antena1 Lusitânia Antena 1 Memória Antena1 Vida Antena 2 Jazz In Antena2 Ópera Rádio Zig Zag RTP Play ZigZag Arquivos + Rede RTP RTP Ensina Museu RTP Newsletters RTP Academia RTP RTP Arena Extra RTP Lab RTP: Nosso Futuro Aplicações móveis RTP Play RTP Notícias Zig Zag Play App RTP Arquivos A empresa Contactos Candidaturas Espontâneas Organograma RTP+ Provedor do Telespetador Informação Financeira Contrato de concessão do serviço público de Rádio e de Televisão Consulta de Conteúdos Cinematográficos Provedor do Ouvinte Sandbox RTP Institucional Identidade gráfica Apoios e Parcerias Anunciar Aplicações móveis Concursos Perguntas frequentes Contactos RGPD Gestão das definições de Cookies Toggle Found %s Results Notícias | Toggle Menu Desporto País Mundo Política Economia Cultura Vídeos Áudios Liga das Nações Eleições Europeias RTP Europa Em Foco Imagem do Dia Galeria Tempo Infografias RSS + Liga das Nações Eleições Europeias RTP Europa Em Foco Imagem do Dia Galeria Tempo Infografias RSS Partilhe no Facebook Partilhe no Twitter Partilhe no Linkedin Partilhe no Whatsapp BCP confirma que Sabadell quer vender participação de 4,08% no banco português Lusa 12 Dez, 2016, 18:57 | Economia O BCP informou já o mercado de que o banco espanhol Sabadell pretende vender uma participação de 4,08% no seu capital social e direitos de voto, confirmando-se assim a informação avançada pela Bloomberg. Em comunicado hoje enviado à Comissão do Mercado de Valores Mobiliários (CMVM), o BCP refere que foi informado pelo Sabadell da sua "intenção de alienar um lote de 38.577.892 ações ordinárias, escriturais e nominativas, sem valor nominal, representativas de 4,08% do capital social e direitos de voto do BCP". O banco português acrescenta que esta alienação vai realizar-se "mediante o lançamento de uma oferta particular das ações", num processo que é "dirigido exclusivamente a investidores qualificados e institucionais" e numa operação que vai ser gerida apenas pelo Citigroup. O Sabadell ficará ainda com 1.353.619 ações do BCP, "representativas de 0,14% do capital social" do banco português e "relativamente às quais, de acordo com os termos da Oferta, o Sabadell assumiu, perante o Citi, um compromisso de não alienação (`lock-up`), sem o consentimento prévio por escrito do Citi, por um período de 90 dias contados da presente data". Na nota, o Sabadell afirma que irá informar o mercado "assim que seja conhecido o resultado da oferta". A agência de informação financeira Bloomberg tinha já avançado esta tarde que o banco espanhol Sabadell ia vender uma participação de 4,1% no BCP, citando os termos de um acordo enviado aos investidores. Esta venda acontece depois de os chineses da Fosun terem adquirido uma participação social de 16,7% em  ...
# 761 0.942998760842627
# Isabel dos Santos confirma pedido da Sonangol para reforçar presença no BCP - Economia - RTP Notícias Toggle Menu Notícias Desporto Televisão RTP1 A Praça da Alegria Telejornal 5 Para a Meia-Noite Joker Cá por Casa Festival da Canção A Nossa Tarde Ver programação RTP1 RTP2 Visita Guiada Literatura Aqui Sociedade Civil Desporto 2 Cinemax Zig Zag Folha de Sala Ver programação RTP2 RTP3 Olhar o Mundo 360º As Horas Extraordinárias Grande Entrevista Grande Área Trio d`Ataque O outro lado Fronteiras XXI Ver programação RTP3 RTP Memória Ver programação de todos os canais RTP África RTP Internacional RTP Açores RTP Madeira Rádio Antena1 Portugalex Maria Flor Pedroso Cinemax Viva a Música David Ferreira a contar O Amor é Entrevista Antena 1 / Jornal de Negócios - Uma Conversa Capital Ver programação Antena1 Antena2 Argonauta A propósito da música A Ronda da Noite Fuga da Arte Jazz a 2 Música Aeterna O Tempo e a Música Quinta Essência Raízes Um Certo Olhar Ver programação Antena2 Antena3 No Ar Antena3 Docs Domínio Público Prova Oral O Disco Disse Portugália A3.30 Manhãs da 3 Indiegente Ver programação Antena3 RDP África Ver toda a programação de rádio RDP Açores RDP Internacional RDP Madeira Antena1 RDP Madeira Antena3 Antena1 Fado Antena1 Lusitânia Antena 1 Memória Antena1 Vida Antena 2 Jazz In Antena2 Ópera Rádio Zig Zag RTP Play ZigZag Arquivos + Rede RTP RTP Ensina Museu RTP Newsletters RTP Academia RTP RTP Arena Extra RTP Lab RTP: Nosso Futuro Aplicações móveis RTP Play RTP Notícias Zig Zag Play App RTP Arquivos A empresa Contactos Candidaturas Espontâneas Organograma RTP+ Provedor do Telespetador Informação Financeira Contrato de concessão do serviço público de Rádio e de Televisão Consulta de Conteúdos Cinematográficos Provedor do Ouvinte Sandbox RTP Institucional Identidade gráfica Apoios e Parcerias Anunciar Aplicações móveis Concursos Perguntas frequentes Contactos RGPD Gestão das definições de Cookies Toggle Found %s Results Direto I Liga. Acompanhe minuto a minuto o Sporting - Rio Ave e oiça o relato na Antena 1 Notícias | Toggle Menu Desporto País Mundo Política Economia Cultura Vídeos Áudios Liga das Nações Eleições Europeias RTP Europa Em Foco Imagem do Dia Galeria Tempo Infografias RSS + Liga das Nações Eleições Europeias RTP Europa Em Foco Imagem do Dia Galeria Tempo Infografias RSS Partilhe no Facebook Partilhe no Twitter Partilhe no Linkedin Partilhe no Whatsapp Isabel dos Santos confirma pedido da Sonangol para reforçar presença no BCP Lusa 01 Dez, 2016, 19:13 | Economia A presidente da Sonangol, Isabel dos Santos, confirmou hoje que a petrolífera angolana pediu um reforço da participação no capital do banco português Millennium BCP, cujo maior acionista é agora o grupo chinês Fosun. Isabel dos Santos falava em Luanda, em conferência de imprensa realizada na sede da empresa para abordar o momento difícil, em termos financeiros, que a petrolífera estatal angolana atravessa, fruto da quebra nas receitas. "A participação da Sonangol no banco Millennium BCP continuará e foi efetuado um pedido de reforço da participação da mesma", disse a presidente do conselho de administração da petrolífera angolana, sem concretizar valores. Partilhar o artigo Isabel dos Santos confirma pedido da Sonangol para reforçar presença no BCP Imprimir o artigo Isabel dos Santos confirma pedido da Sonangol para reforçar presença no BCP Enviar por email o artigo Isabel dos Santos confirma pedido da Sonangol para reforçar presença no BCP Aumentar a fonte do artigo Isabel dos Santos confirma pedido da Sonangol para reforçar presença no BCP Diminuir a fonte do artigo Isabel dos Santos confirma pedido da Sonangol para reforçar presença no BCP Ouvir o artigo Isabel dos Santos confirma pedido da Sonangol para reforçar presença no BCP Pub Últimos Artigos Últimas Últimas + Lidas + Coment. 1 Aldeia da Sertã regressa à rede telefónica dois anos após incêndios 2 Doze distritos sob alerta amarelo por risco de incêndio 3 Ataque com faca em França faz um morto ...
# 770 0.9541511771995044
# BCP - DN Diário de Notícias Menu Pesquisar Covid-19 Poder País Mundo Cultura Pré-publicações Desportos Opinião Vida e futuro Ócio Life Edição do dia 1864 Fake News Cidades Insider Multimédia Login Minha conta Alterar Dados Pessoais Mudar de Utilizador Sair Pesquisar Fechar Diário de Notícias Terça-feira, 26 de Março de 2018, Nº 54 161 BCP Banca BCP vai passar a cobrar comissões a contas de penhoras Novos custos deverão ter início a 15 de setembro e vão pesar mais no bolso dos devedores, sobretudo os de rendimentos mais baixos. Banca Clientes com mais de 10 mil euros no BCP começam a pagar comissão Economia Lucros do BCP diminuem 77% para 35,3 milhões de euros no 1.º trimestre Os lucros do BCP caíram 77,1% para 35,3 milhões de euros no primeiro trimestre de 2020, uma diminuição face aos 153,8 milhões de euros do mesmo período do ano passado, refletindo os efeitos da pandemia de covid-19. Moody's. Banca nacional perde brilho, BCP e CGD podem precisar de mais apoios Contas de 2019 Bancos ganharam mais de 5,2 milhões por dia Premium BCP Berardo e Constâncio: dois maus da fita não explicam a história toda Comissão de Inquérito Vara diz que Banco de Portugal "não tinha de se meter" no crédito a Berardo inquérito "Velhaca maledicência". Sócrates nega interferência no BCP O antigo primeiro-ministro respondeu ao ex-administrador do BCP Filipe Pinhal que na audição parlamentar à gestão da Caixa Geral de Depósitos sugeriu que Sócrates terá influenciado Joe Berardo a reforçar a sua posição no banco. Filipe Pinhal: "Recusei empréstimos a Berardo e Constâncio correu comigo" Comissão de Inquérito "Berardo foi o presidente do BCP entre 2008 e 2012" O antigo presidente do BCP Filipe Pinhal afirmou que era difícil contrariar Berardo e que poder do empresário beneficiava José Sócrates. Constâncio diz que não tinha poder para anular crédito a Berardo Caso Berardo "Indispensável". Partidos querem nova audição a Vítor Constâncio Joe Berardo "Sou advogado e amigo do comendador Berardo" poder Quem é o advogado que mandou calar Berardo e o ajudou na audição Parlamento Joe Berardo diz que "pessoalmente" não tem dívidas Joe Berardo diz que "pessoalmente não tem dívidas". E recusa abdicar da coleção de arte para pagar aos bancos. Berardo: “Tentei ajudar os bancos. Mas não ia arriscar a minha vida” BCP Lucros do BCP disparam 80% no primeiro trimestre para 154 milhões de euros Justiça Bancos põem ação para cobrar dívidas a Joe Berardo Justiça Credor pede suspensão da venda da Herdade de Rio Frio Banca Acionistas do BCP dão primeiro passo para distribuição de dividendos Os acionistas do Millennium bcp, reunidos esta segunda-feira em assembleia geral extraordinária, aprovaram os dois pontos da ordem de trabalhos, abrindo caminho para a distribuição de dividendos. AG do BCP arrancou com 62% capital presente Banca Caixa e BCP dizem que ainda há obstáculos a superar para darem dividendos Os dois bancos têm vontade de distribuir dividendos no próximo ano. Mas realçam que as instituições portuguesas estão em desvantagem face aos pares europeus. financiamento BCP não empresta mais dinheiro a clubes de futebol Banca Miguel Maya promete entregar mais lucros aos acionistas do BCP BCP Nuno Amado passa a chairman, Miguel Maya a CEO Banca BCP e dono do Novo Banco na corrida à filial espanhola da CGD A filial espanhola é uma das três operações no estrangeiro que a Caixa se comprometeu a vender junto da Comissão Europeia. Carta de Bruxelas alerta para fraqueza dos bancos nacionais Bolsa Sonangol tem 1,9 mil milhões na Galp e BCP. E não vai vender Banca Maiores bancos com lucros acumulados de 700 milhões de euros em 2017 Banca Maiores bancos reduzem dois mil trabalhadores e fecham 269 agências Balanço Bancos cobraram mais 100ME em comissões em 2017 face a 2016 Em média, em cada dia de 2017, bancos cobraram cinco milhões de euros em comissões. Maiores bancos com lucros acumulados de 700 milhões de euros em 2017 Banca BCP à procura de investidores estrangeiros para se financ ...
# 797 0.9876084262701363
# ...
# 80 0.2702702702702703
# Mota-Engil lança novas obrigações para captar até 95 ME - Economia - Notícias - RTP Rádio e Televisão de Portugal Notícias Desporto TV Rádio RTP Play Mais RTP Entretenimento Extra , Festival da Canção , Os Nossos Dias , Cook Off - Duelo de Sabores , Água de Mar , Bem-vindos a Beirais , Agora Nós , Há Tarde , Toca a Todos , O Povo Que Ainda Canta , NOS Alive , Super Bock Super Rock , 5 Para a Meia-Noite , Cinemax , Passatempos , Concursos, Recomendamos RTP Arquivo, Ensina RTP , Academia RTP , Estado do Sítio , Teletexto A Empresa   Contactos | Feedback | Imprensa | RTP+ | Código Ética | Contrato Concessão TV & Lei da Rádio | Provedores | Conselho Opinião   | Termos e Condições |  Recrutamento Zig Zag Vídeos , Receitas , Ruca , Imagina , Jogos , Mini Guia de TV , Facebook Museu & Documentação Museu Virtual | Estúdio Virtual | Arquivo Histórico | Centro de Documentação | Arquivo de Música Escrita | Exposição 50 Anos | Carro de Exteriores | Históricos Mobile & Internet TV 5i App Second Screen , Aplicação RTP Play , Aplicação Android ; Aplicação iPhone/iPad ; Versões móveis: m.rtp.pt ; Widget MEO ; Widget Samsung RTP Notícias   Galeria | O Meu Telejornal | O Meu Noticiário | Diretos | Programas | RSS Início Em Foco País Em Destaque 25 de Abril Mundo Em Destaque Eleições no Brasil Estado Islâmico Política Em Destaque Europeias Primárias PS Economia Em Destaque Bolsa Orçamento do Estado Cultura Em Destaque Lifestyle Desporto Em Destaque Futebol Nacional Benfica Porto Sporting Taça da Liga 1.ª Liga 2.ª Liga Seniores Distritais Futebol Internacional Em Destaque Champions Liga Europa Seleção Euro2016 Liga Espanhola Liga Inglesa Liga Francesa Liga Italiana Liga Alemã Motores Ténis Fórmula 1 Outras Modalidades Rali 2015 Trânsito Tempo Em Destaque Serviços meteorológicos Imagem do Dia País Mundo Desporto RTP / Início / Economia Mota-Engil lança novas obrigações para captar até 95 ME Lusa 15 Jun, 2015, 20:53 A Mota-Engil vai emitir até 190 mil novas obrigações, com o valor nominal unitário de 500 euros e o valor global até 95 milhões de euros com maturidade até 2020, informou hoje a construtora. As novas obrigações vão ser colocadas no mercado através de duas operações: uma oferta pública de subscrição de até 140 mil novas obrigações, cujo valor pode ascender a 70 milhões de euros, e uma oferta pública de troca parcial e voluntária tendo por objeto até 50 mil `Obrigações Taxa Fixa Mota-Engil 2013/2016`, com o valor nominal unitário de 500 euros e global de até 25 milhões de euros. As novas obrigações contam com uma taxa de juro fixa bruta de 3,90% ao ano, maturidade em 03 de fevereiro de 2020, e vão ser admitidas à negociação na Euronext Lisbon, lê-se no comunicado enviado pela construtora à Comissão do Mercado de Valores Mobiliários (CMVM). No que toca à oferta pública de troca, a cada obrigação `Taxa Fixa Mota-Engil 2013/2016` vai corresponder, a título de contrapartida, uma nova obrigação e um prémio em numerário de 14,64 euros. As duas ofertas públicas vão decorrer entre 17 e 30 de junho e vão ser liquidadas a 03 de julho de 2015. "Com a oferta pública de subscrição, a Mota-Engil visa obter fundos para financiar a sua atividade corrente e de expansão internacional, bem como dar prosseguimento à estratégia de alongamento de maturidade da sua dívida, de modo a alinhá-la melhor com a geração de `cash-flow` [fluxos de caixa]", revelou a empresa. Já a oferta pública de troca "visa permitir à Mota-Engil a substituição de parte da sua dívida com vencimento em 2016 por dívida com vencimento em 2020". O Caixa -- Banco de Investimento é o intermediário financeiro responsável pela coordenação global e assistência à oferta pública de subscrição e à oferta pública de troca.   . Corrigir . Leia-me . Imprimir . Enviar . Partilhar . Aumentar . Diminuir Últimas Notícias de Economia Artigo de Vídeo Santander prepara-se para evolução negativa na Grécia Ontem às 21:55 Artigo de Vídeo Editor do Finantial Times diz que há fortes probabilidades de a Grécia nã ...
# 89 0.30067567567567566
# Ganhos da Mota-Engil apoiam subida de 1% do PSI20 Últimas Portugal Desporto Mundo Opinião Dinheiro Sociedade Artes Menu Ganhos da Mota-Engil apoiam subida de 1% do PSI20 No fecho da semana, 16 das 18 cotadas do PSI20 ficaram em terreno positivo e duas recuaram. Dinheiro Vivo 01 Março 2019 — 19:01 O principal índice da bolsa de Lisboa (PSI20) encerrou a sessão desta sexta-feira a avançar 1,02% para 5.238,54 pontos, com a Mota-Engil a subir quase 6%. Leia mais em Dinheiro Vivo a sua marca de economia Mais Artigos monarquia britânica "Fico muito triste que tenha acabado assim". Príncipe Harry fala no afastamento da família real Luanda Leaks "Roubalheira organizada". Ana Gomes acusa PGR, CMVM e Banco de Portugal de conivência com Isabel dos Santos Campeonato Rio Ave vence Boavista embalado com rasgo de Diego Lopes futebol Juventus reforça liderança em Itália com dois golos de Ronaldo Luanda Leaks Isabel dos Santos terá desviado dinheiro de Angola Premium Táfico de espécies protegidas Papagaios e periquitos lideram importações ilegais, mas há quem prefira um puma ou um macaco Dakar 2020 Autópsia realizada. Corpo de Paulo Gonçalves chega a Portugal no início da semana Concerto cancelado As mazelas físicas que podem pôr em risco a digressão europeia de Madonna Junto ao rio Ferreira Todo-o-terreno cai numa ravina. Um morto e três feridos graves em Gondomar automóvel Anúncios de carros elétricos usados desaparecem em 70 dias Em entrevista "Estão a transformar a família real num Walmart com uma coroa", diz pai de Meghan I Liga Golo depois dos 90 minutos dá empate ao Famalicão na receção ao Marítimo Concerto "Até terça. Façam figas". Madonna cancela concerto desta noite no Coliseu de Lisboa Moda Apropriação cultural? Marca japonesa criticada por perucas de modelos Cultura Morreu histórico produtor do cinema português Henrique Espírito Santo Global Media Group, 2018  © Todos os Direitos Reservados
# 245 0.8277027027027027
# Ganhos da Mota-Engil apoiam subida de 1% do PSI20 Últimas Portugal Desporto Mundo Opinião Dinheiro Sociedade Artes Menu Ganhos da Mota-Engil apoiam subida de 1% do PSI20 No fecho da semana, 16 das 18 cotadas do PSI20 ficaram em terreno positivo e duas recuaram. Dinheiro Vivo 01 Março 2019 — 19:01 O principal índice da bolsa de Lisboa (PSI20) encerrou a sessão desta sexta-feira a avançar 1,02% para 5.238,54 pontos, com a Mota-Engil a subir quase 6%. Leia mais em Dinheiro Vivo a sua marca de economia Mais Artigos Itália A primeira vítima europeia do coronavírus é italiana jogos 'Jackpot' de 51 milhões de euros no próximo sorteio do Euromilhões Morte de Vasco Pulido Valente Reações. "Um dos intelectuais mais marcantes da vida pública portuguesa" João Moura SOS Animal vai constituir-se assistente no processo criminal contra cavaleiro João Moura Orçamento da UE Orçamento da UE. Costa disse "não" à proposta em nome do grupo dos Amigos da Coesão Atletismo Yulimar Rojas bate recorde mundial do triplo salto homicídio Fátima, 7 anos, abusada e torturada. A morte que está a chocar o México Conselho Europeu Acordo sobre orçamento europeu? Orbán já usa a palavra "milagre" País Lidl alerta para sorteio fraudulento que pede dados pessoais a clientes "Precisamos de mais tempo" Conselho Europeu termina em Bruxelas sem acordo sobre orçamento. "Precisamos de mais tempo" Coronavírus Surto "sob controlo". OMS preocupada com casos fora da China Coronavírus Dez localidades italianas encerram espaços públicos. Há 16 pessoas infetadas Justiça Hells Angels. Saída de juíza dita repetição da fase de instrução Óbito Marcelo lembra Pina Moura como um "lutador pela liberdade e político relevante" Cultura Vasco Pulido Valente. Marcelo elogia "impiedosa independência crítica" Global Media Group, 2020  © Todos os Direitos Reservados
# 257 0.8682432432432432
# Mota-Engil pode ter de pagar indemnização em caso de corrupção no Peru | Construção | PÚBLICO Ir para o conteúdo Ir para navegação principal Abrir menu Abrir pesquisa Público Assine já Entrar {{userName}}{{^userName}}A minha conta{{/userName}} Partilhar notícia 1200 partilhas Partilhar no Facebook Partilhar no Twitter Partilhar no WhatsApp Partilhar no LinkedIn Enviar por email Comentar Construção Mota-Engil pode ter de pagar indemnização em caso de corrupção no Peru Se uma ex-directora comercial da Mota-Engil Peru for acusada num caso de corrupção que envolve o alegado pagamento de luvas para adjudicação de obras públicas, a construtora poderá ser obrigada a compensar o Estado peruano. Ana Brito 23 de janeiro de 2019 Partilhar notícia Partilhar no Facebook Partilhar no Twitter Partilhar no WhatsApp Partilhar no LinkedIn Enviar por email Comentar Foto A Mota-Engil, presidida por António Mota, diz esperar "que se conclua pelo comportamento eticamente responsável da empresa" fvl Fernando Veludo/NFACTOS A notícia chegou às páginas dos jornais peruanos em Janeiro de 2018. Há precisamente um ano, o Ministério Público do Peru realizava buscas em mais de 40 imóveis relacionados com 17 pessoas investigadas por suspeitas de corrupção e pagamento de luvas a um ex-assessor do Ministério de Transportes e Comunicações daquele país. Atingiu o seu limite de artigos A liberdade precisa do jornalismo. Precisa da sua escolha. Não deixe que as grandes questões da sociedade portuguesa lhe passem ao lado. Registe-se e aceda a mais artigos ou assine e tenha o PÚBLICO todo, com um pagamento mensal. Pense bem, pense Público. Assine já Registe-se Já é assinante? Inicie aqui PUB A carregar... PUB A carregar... A tese do Ministério Público peruano (que uma juíza do tribunal especializado em delitos de corrupção de funcionários públicos do Peru considerou credível o bastante para autorizar as buscas e apreensões) foi a de que, entre 2011 e 2014, existiu um grupo denominado “Club de la Construcción”, formado por diversas empresas (entre elas as brasileiras Andrade Gutierrez e Queiroz Galvão, duas das investigadas na Operação Lava Jato) que realizaram acordos ilegais e licitações fraudulentas com vista a repartir entre si as adjudicações de várias obras lançadas pelo Ministério dos Transportes do Peru. Isto mediante o alegado pagamento de uma percentagem de 2,9% do valor da obra ao assessor do então ministro Carlos Paredes. Presidente do Peru demite-se para evitar destituição PUB A carregar... Entre os vários suspeitos figura Norma Zeppilli del Mar que era, à data das buscas, directora comercial e de desenvolvimento de negócios da Mota-Engil Peru, cargo que exerceu entre Setembro de 2013 e Fevereiro de 2018, de acordo com o seu perfil na rede social LinkedIn (antes disso, entre Janeiro e Agosto de 2013, foi directora comercial e, entre Setembro de 2007 e Agosto de 2013, gerente comercial). De acordo com a ordem judicial de realização de buscas a que o PÚBLICO teve acesso, Zepilli foi identificada pela justiça peruana como a funcionária da Mota-Engil que se terá alegadamente reunido com os funcionários das outras construtoras para decidirem entre si que obras caberiam a cada empresa. No mais recente desenvolvimento do caso, no mês passado, a mesma magistrada, a juíza María de los Ángeles Álvarez, decidiu que 12 das empresas investigadas deveriam ser consideradas civilmente responsáveis no processo, e chamadas a contribuir para o pagamento de eventuais indemnizações, caso venha a comprovar-se a culpabilidade dos suspeitos. Entre elas, a Mota-Engil Peru, que contestou a decisão. Questionada, fonte oficial do grupo português referiu que “a Mota-Engil Peru, como todas as empresas de construção, foram incluídas na investigação como possível terceiro civilmente responsável, decisão judicial que está em recurso perante instância superior”. A empresa presidida por António Mota sublinhou que esta decisão do tribunal “não implica per se a responsabilidade da empresa  ...
# 273 0.9222972972972973
# Mota-Engil fecha acordo com chineses da CCCC por 170 milhões | Empresas | PÚBLICO Ir para o conteúdo Ir para navegação principal Abrir menu Abrir pesquisa Público Assine já Entrar {{userName}}{{^userName}}A minha conta{{/userName}} Partilhar notícia 1200 partilhas Partilhar no Facebook Partilhar no Twitter Partilhar no WhatsApp Partilhar no LinkedIn Enviar por email Comentar Empresas Mota-Engil fecha acordo com chineses da CCCC por 170 milhões Empresa estatal chinesa vai pagar 170 milhões de euros para ficar com uma posição de menos de 30% no grupo. Acordo prevê venda de 55 milhões de títulos a 3,08 euros cada, o dobro do valor que têm no mercado. Luísa Pinto 27 de novembro de 2020 Partilhar notícia Partilhar no Facebook Partilhar no Twitter Partilhar no WhatsApp Partilhar no LinkedIn Enviar por email Comentar Foto Família Mota vende uma parte da sua participação a empresa estatal chinesa Adriano Miranda Ainda não é oficial, porque faltam as autorizações dos reguladores e a necessária aprovação em assembleia-geral (AG), mas a Mota-Engil já anunciou ter concluído com a China Communications Construction Company (CCCC) o acordo de parceria estratégica que vai permitir àquele que é um dos maiores grupos de infra-estruturas do mundo ficar com uma posição relevante no capital da construtora portuguesa. Atingiu o seu limite de artigos A liberdade precisa do jornalismo. Precisa da sua escolha. Não deixe que as grandes questões da sociedade portuguesa lhe passem ao lado. Registe-se e aceda a mais artigos ou assine e tenha o PÚBLICO todo, com um pagamento mensal. Pense bem, pense Público. Assine já Registe-se Já é assinante? Inicie aqui PUB A carregar... PUB A carregar... Os chineses vão pagar cerca de 170 milhões de euros para comprar 55 milhões de acções do grupo a 3,08 euros por cada acção.  O preço pago por acção é mais do dobro daquele com que fechou, por exemplo, a sessão desta quinta-feira: 1,49 euros. Depois do anúncio da conclusão dos termos do acordo, a Mota-Engil está a valorizar 14,5%, a cotar nos 1,71 euros.  O anúncio destas negociações havia sido feito em Agosto passado , altura em que a empresa informou, também, da intenção de fazer um aumento de capital de mais 100 milhões de acções. Este aumento de capital terá de ser aprovado numa AG, a convocar nos próximos dias, para que, no final, a família Mota (que actualmente tem 65% do capital) fique com 40% das participações e a CCCC fique com 30%.  A família Mota abdica, assim, de uma parte da sua participação, mas manterá uma posição maioritária. E, no final, a construtora verá reforçadas “as suas capacidades financeiras, técnicas e comerciais”, com o objectivo de “aumentar as suas actividades em todos os mercados e abrir novas oportunidades para novos desenvolvimentos”, conforme argumentou a empresa ao mercado , quando anunciou estas negociações . PUB A carregar... A  efectividade do acordo está agora dependente da confirmação por parte da Comissão do Mercados de Valores Mobiliários (CMVM) que a operação não impõe para a CCCC a obrigação de lançamento de uma oferta pública de aquisição sobre o capital da empresa portuguesa. O total de capital que está em freee-float, isto é, na posse de accionistas minoritários é de 23,4%. tp.ocilbup@otnip.asiul Partilhar notícia Partilhar no Facebook Partilhar no Twitter Partilhar no WhatsApp Partilhar no LinkedIn Enviar por email Comentar Sugerir correcção Em destaque {{#isOpiniao}} {{#autores}} {{#autores.0.imagem}} {{/autores.0.imagem}} {{/autores}} {{/isOpiniao}} {{^isOpiniao}} {{#imagem}} {{/imagem}} {{/isOpiniao}} {{#fonteImagem}} {{fonteImagem}} {{/fonteImagem}} {{#rubrica}} {{rubrica}} {{/rubrica}} {{^rubrica}} {{#seccao}} {{seccao}} {{/seccao}} {{/rubrica}} {{#isOpiniao}} {{/isOpiniao}}{{#emDirecto}} Em directo {{/emDirecto}}{{{titulo}}} Mais artigos Mais destaques Público Seguir Facebook Twitter Google+ LinkedIn Instagram YouTube RSS Mapa Política Sociedade Local Economia Mundo Cultura-Ípsilon Desporto Ciência Tecnologia Fugas Li ...
# 288 0.972972972972973
# Done!

# %% [markdown]
# ---
#
# # criar coluna keywords

# %%
def count_weight(probNews, type):
    weight = 0
    # noticia so com frases q têm aliases
    if probNews <= 0.6:
        weight += 2
    elif probNews < 0.9:
        weight -= 0.15
    if "PER" in type:
        weight += 1.3
    if "ORG" in type:
        weight += 1.1
    if "LOC" in type:
        weight += 1.4
    if "WORD" in type:
        weight += 0.85
    return weight

def sentiment_weight(probNews):
    if probNews <= 0.6:
        return 1.1
    elif probNews == 1:
        return 1
    else:
        return 0.95


def keywords(lista):
    ner = {}
    for news in lista:
        keywords = news["newsNER"]
        sentiment = news["newsSentiment"]
        for type, words in keywords.items():
            for word in words:
                # normalizar word
                if word.lower() in ner:
                    word = word.lower()
                elif word.title() in ner:
                    word = word.title()
                elif word.upper() in ner:
                    word = word.upper()

                # adicionar word
                if word in ner:
                    ner[word]["count"] += 1
                    ner[word]["sentiment"] += sentiment * sentiment_weight(news["newsProbability"])
                    ner[word]["type"].add(type)
                    if news["newsSource"] not in ner[word]["source"]:
                        ner[word]["source"][news["newsSource"]] = 1
                    else:
                        ner[word]["source"][news["newsSource"]] += 1
                    if news["linkToArchive"][42:len(news["linkToArchive"])-10] not in ner[word]["news_id"]:
                        ner[word]["news_id"].add(news["linkToArchive"][42:len(news["linkToArchive"])-10])
                        ner[word]["news"].add(news["linkToArchive"])
                    if news["tstamp"] in ner[word]["date"]:
                        ner[word]["date"][news["tstamp"]] += 1
                    else:
                        ner[word]["date"][news["tstamp"]] = 1
                    ner[word]["weight"] += count_weight(news["newsProbability"], type)

                else: #not seen
                    ner[word] = {"count": 1,
                                 "sentiment": sentiment * sentiment_weight(news["newsProbability"]),
                                 "type": {type},
                                 "source": {news["newsSource"]: 1},
                                 "news": {news["linkToArchive"]},
                                 "date": {news["tstamp"]: 1},
                                 "news_id": {news["linkToArchive"][42:len(news["linkToArchive"])-10]},
                                 "weight": count_weight(news["newsProbability"], type)}

                    # muitas coisas estao mal classificas como LOC devia ser ORG e assim...
    
    qtyNews = len(lista)
    for word, data in ner.items():
        del data["news_id"]
        data["filter"] = (data["weight"]/2) / qtyNews # >= 0.1 = "aparecer em 10% das noticias"
        data["sentiment"] = max(min(data["sentiment"]/data["count"], 1), -1)
    filtered_ner = {word: data for word, data in ner.items() if data["count"] > 1}

    return filtered_ner

df["keywords"] = df["news"].map(keywords)

# %%
df["keywords"].iloc[0]["dinheiro"].keys()
# Out:
# dict_keys(['count', 'sentiment', 'type', 'source', 'news', 'date', 'weight', 'filter'])

# %% [markdown]
# when saving the df, parquet adds all the keys to all the diciotnarys, so if a word doents appear for ex. in EDP, it will appear in the dictionary as for example {"notEDP": None, ...}

# %%
df.to_parquet("data05.parquet")

df = pd.read_parquet("data05.parquet")
df["keywords"] = df["keywords"].map(lambda dic: {key: dic[key] for key in dic.keys() if dic[key] != None})
df
# Out:
#                                                                      aliases  \
# companies
# Banco Comercial Português                   [Banco Comercial Português, BCP]
# Galp Energia                                            [Galp Energia, GALP]
# EDP                        [EDP, Energias de Portugal, Electricidade de P...
# Sonae                                                           [Sonae, SON]
# Mota-Engil                                                 [Mota-Engil, EGL]
#
#                                                                         news  \
# companies
# Banco Comercial Português  [{'ExtractedText': 'DN   13 de Setembro de 200...
# Galp Energia               [{'ExtractedText': 'RTP Galp reforça posição n...
# EDP                        [{'ExtractedText': 'DN-Sinteses Negocios 9 de ...
# Sonae                      [{'ExtractedText': 'DN-Sinteses 5 de Março de ...
# Mota-Engil                 [{'ExtractedText': 'RTP Lucro da Mota-Engil so...
#
#                                                                     keywords
# companies
# Banco Comercial Português  {'03 Mar': {'count': 2.0, 'date': {'201503': 2...
# Galp Energia               {'00h00': {'count': 7.0, 'date': {'201004': 1....
# EDP                        {'00h00': {'count': 4.0, 'date': {'201004': No...
# Sonae                      {'00h00': {'count': 3.0, 'date': {'201004': No...
# Mota-Engil                 {'15h30': {'count': 2.0, 'date': {'201509': 1....

# %% [markdown]
# ---

# %%
#sentimentos = 0
#for key in df.iloc[-1,2].keys():
#    sentimentos += df.iloc[-1,2][key]["sentiment"]
#sentimentos, sentimentos/len(df.iloc[-1,2].keys())

# %%
#[x for x in df["keywords"].iloc[-1].keys() if "mota" in x.lower()]
#df["keywords"].iloc[-1]["Mota-Engil África"]
